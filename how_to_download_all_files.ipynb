# %%
import pandas as pd
from sec_edgar_downloader import Downloader

# %%
# This is the file given on the word doc of the project:
sec = pd.read_excel (r'C:\Users\rayan\Downloads\CIK_list.xlsx')

# %%
sec.head(10)
# Out:
#    Unnamed: 0  CIK Number                             Entity Name  \
# 0           0        2110                    COLUMBIA ACORN TRUST
# 1           1        2646        Voya INTERMEDIATE BOND PORTFOLIO
# 2           2        2663  VOYA GOVERNMENT MONEY MARKET PORTFOLIO
# 3           3        2664                     Voya VARIABLE FUNDS
# 4           4        2691         LORD ABBETT AFFILIATED FUND INC
# 5           5        2768              FRANKLIN HIGH INCOME TRUST
# 6           6        3521                             ALGER FUNDS
# 7           7        3794                      AB BOND FUND, INC.
# 8           8        4405                              AMCAP FUND
# 9           9        4568                  AMERICAN BALANCED FUND
#
#                                 Address_1         City State    Zip Code
# 0                   227 W MONROE STE 3000      CHICAGO    IL       60606
# 1                      ING FUNDS SERVICES   SCOTTSDALE    AZ       85258
# ...

# %%
loader = Downloader()

for i in sec['CIK Number']:
    loader.get("13F-HR", "i")
# Out:
# Skipping full submission download for '0000950131-01-501414' due to network error: 404 Client Error: Not Found for url: https://www.sec.gov/Archives/edgar/data/0001038614/000095013101501414/0000950131-01-501414.txt.
# Skipping filing detail download for '0000950131-01-501414' due to network error: 404 Client Error: Not Found for url: https://www.sec.gov/Archives/edgar/data/0001038614/000095013101501414/d13fhr.txt.
# Skipping full submission download for '0000950131-01-000921' due to network error: 404 Client Error: Not Found for url: https://www.sec.gov/Archives/edgar/data/0001038614/000095013101000921/0000950131-01-000921.txt.
# Skipping filing detail download for '0000950131-01-000921' due to network error: 404 Client Error: Not Found for url: https://www.sec.gov/Archives/edgar/data/0001038614/000095013101000921/0001.txt.
# ...
